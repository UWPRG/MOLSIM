# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_excel('gaff_uff.xlsx')
data
# Out:
#         BOND   GAFF    UFF    EXP
# H-H      H-H  1.100  0.708  0.741
# H3C-CH3  C-C  1.537  1.519  1.526
# H3C-CH3  C-H  1.092  1.110  1.088
# H2C-CH2  C-C  1.325  1.331  1.339
# H2C-CH2  C-H  1.087  1.085  1.085
# HC-CH    C-C  1.205  1.205  1.203
# HC-CH    C-H  1.058  1.058  1.061

# %% [markdown]
# ### The bond distances for Hydrogen calculated using the following theory and basis sets

# %%
data=pd.read_excel('hydrogen.xlsx')
data
# Out:
#            321   STO-36  LANL2DZ   6-31Gd  6-31Gdp
# B3LYP  0.74623  0.72838  0.74280  0.74279  0.74280
# MP2    0.74136  0.72374  0.73835  0.73752  0.73393
# M062X  0.74145  0.72207  0.73747  0.73653  0.73649
# CCSD   0.74981    error  0.74730  0.74621  0.73845

# %% [markdown]
# The value closest to the experimental value is for MP2-321

# %% [markdown]
# ### The computing time for the above calculations

# %%
data=pd.read_excel('H2-time.xlsx')
data
# Out:
#         321  STO3G  LANLDZ  631Gd  631Gdp
# B3LYP  12.8   12.4    15.3   12.4    15.3
# MP2    10.3   13.6    14.8   14.1    12.9
# M062X   9.7   12.1    13.4   12.6    11.5
# CCSD   19.7    0.0    19.2   18.7    24.3

# %% [markdown]
# ### The bond distances for Ethane calculated using the following theory and basis sets.
# The first 4 rows are for C-C bonds, the next 4 rows are for C-H bonds

# %%
data=pd.read_excel('ethanebonds.xlsx')
data
# Out:
#    C-Cbonds        321   STO-36  LANL2DZ   6-31Gd  6-31Gdp
# 0     B3LYP    1.54477  1.55123  1.54353  1.53115  1.53058
# 1       MP2    1.55083  1.55541  1.56173  1.52527  1.52345
# 2     M062X    1.54321  1.54084   1.5392  1.52574  1.52546
# 3      CCSD    1.55624  1.56247  1.56506  1.52904  1.52671
# 4  C-Hbonds  321.00000   STO-36  LANL2DZ   6-31Gd  6-31Gdp
# 5     B3LYP    1.09557  1.10098  1.09797  1.09627  1.09511
# 6       MP2    1.09481  1.10309  1.10492  1.09327  1.08872
# 7     M062X    1.09412   1.0955  1.09488   1.0939  1.09313
# 8      CCSD    1.09932  1.11178  1.10926  1.09686  1.09047

# %% [markdown]
# #### The values closest to experimental is for MP2-631gDP

# %% [markdown]
# ### The computing time for the above calculations

# %%
data=pd.read_excel('ethane_calculatingtime.xlsx')
data
# Out:
#         321  STO-3G  LANL2DZ       6-31Gd  6-31Gdp
# B3LYP  21.6    31.4     41.9         55.6     54.6
# MP2    17.8    22.0     19.6         22.7     30.5
# M062X  32.2    26.9     35.9         42.4     52.3
# CCSD   51.3    50.4     57.3  2 min 17.3s  6m51.7s

# %% [markdown]
# ### The bond distances for Ethene calculated using the following theory and basis sets.
# The first 4 rows are for C-C bonds, the next 4 rows are for C-H bonds

# %%
data=pd.read_excel('ethenebonds.xlsx')
data
# Out:
#    C-Cbonds        321   STO-36  LANL2DZ   6-31Gd  6-31Gdp
# 0     B3LYP    1.32941  1.33309  1.34839  1.33094  1.33016
# 1       MP2    1.34115  1.34529  1.36762  1.33662  1.33535
# 2     M062X    1.32800  1.32245  1.34311  1.32744  1.32687
# 3      CCSD    1.34387   1.3549   1.3697   1.3379  1.33646
# 4  C-Hbonds  321.00000   STO-36  LANL2DZ   6-31Gd  6-31Gdp
# 5     B3LYP    1.08586  1.09728  1.08841  1.08749  1.08666
# 6       MP2    1.08560  1.09832  1.09413  1.08505  1.08065
# 7     M062X    1.08468  1.09227  1.08628   1.0859  1.08541
# 8      CCSD    1.08976  1.10609  1.09782  1.08803  1.08188

# %% [markdown]
# #### The values closest to experimental is for MP2-631gDP

# %% [markdown]
# ### The computing time for the above calculations

# %%
data=pd.read_excel('ethene_calculatingtime.xlsx')
data
# Out:
#         321  STO-3G  LANL2DZ     6-31Gd    6-31Gdp
# B3LYP  20.4    15.7     17.7       25.9       28.4
# MP2    17.9    17.6     19.4         23       25.4
# M062X  18.6    17.1     20.1       22.5       25.1
# CCSD   42.0    41.8     45.3  1min18.8s  2min27.4s

# %% [markdown]
# ### The bond distances for Ethyne calculated using the following theory and basis sets.
# The first 4 rows are for C-C bonds, the next 4 rows are for C-H bonds

# %%
data=pd.read_excel('ethynebonds.xlsx')
data
# Out:
#    C-Cbonds        321   STO-36  LANL2DZ   6-31Gd  6-31Gdp
# 0     B3LYP    1.20366   1.2005  1.22228  1.20498  1.20535
# 1       MP2    1.22169  1.21829  1.24606  1.21768  1.21855
# 2     M062X    1.20226   1.1926  1.21687  1.20193  1.20235
# 3      CCSD    1.21683  1.21263  1.23941  1.21151  1.21213
# 4  C-Hbonds  321.00000   STO-36  LANL2DZ   6-31Gd  6-31Gdp
# 5     B3LYP    1.06224  1.08084  1.06783  1.06664  1.06572
# 6       MP2    1.06429   1.0807  1.07186  1.06614  1.06245
# 7     M062X    1.06209  1.07782  1.06706  1.06712  1.06643
# 8      CCSD    1.06837  1.08783  1.07543   1.0687  1.06365

# %% [markdown]
# #### The values are closest to B3LYP-321

# %% [markdown]
# ### The computing time for the above calculations

# %%
data=pd.read_excel('ethyne_calculatingtime.xlsx')
data
# Out:
#      321    sto    ln        6d        6dp
# b   15.3   19.3  16.9      18.7       19.9
# mp  18.0   22.7  19.3      22.8       23.5
# mo  16.2  20.1s  17.9      19.8       20.9
# cc  46.3   40.8  48.0  1min7.8s  1min29.1s

# %% [markdown]
# #### The fastest calculation was for Hydrogen M062X-321 = 9.7s

# %% [markdown]
# ### The graphs for Hydrogen according to the basis sets in the following order:
# 1)321
# 2)6-31Gd
# 3)6-31Gdp
# 4)LANL2DZ
# 5)STO-3G

# %%
names = [[] for i in range(0,5)]

# %%
names[0] = ['hy/hb3.txt','hy/hcc3.txt','hy/hmo3.txt','hy/hmp3.txt']
names[1] = ['hy/hb6d.txt','hy/hcc6d.txt','hy/hmo6d.txt','hy/hmp6d.txt']
names[2] = ['hy/hb6dp.txt','hy/hcc6dp.txt','hy/hmo6dp.txt','hy/hmp6dp.txt']
names[3] = ['hy/hblan.txt','hy/hcclan.txt','hy/hmolan.txt','hy/hmplan.txt']
names[4] = ['hy/hbsto.txt','abc','hy/hmosto.txt','hy/hmpsto.txt']
legends = ['B3LYP','CCSD','M062X','MP2']
legends1 = ['B3LYP','M062X','MP2']

# %%
for name in names:
    plt.figure()
    j=0
    for i in range(len(name)):
        if name[i] == 'abc':
            j=1
            continue
        else:
            data = pd.read_csv(name[i], sep=' ',skipinitialspace=True, skiprows=6)
            data.columns = ['a','b','c']
            data.b = data.b * 627.509
            plt.plot(data.a,data.b)
            plt.xlabel('Optimization Step')
            plt.ylabel('Energy (kcal/mol)')
    if j==1:
        plt.legend(legends1)
    else:
        plt.legend(legends)
    plt.show()

# %% [markdown]
# ### The graphs for Ethane according to the basis sets in the following order:
# 1)321
# 2)6-31Gd
# 3)6-31Gdp
# 4)LANL2DZ
# 5)STO-3G

# %%
names = [[] for i in range(0,5)]

# %%
names[0] = ['ethane/b3.txt','ethane/cc3.txt','ethane/mo3.txt','ethane/mp3.txt']
names[1] = ['ethane/b6d.txt','ethane/cc6d.txt','ethane/mo6d.txt','ethane/mp6d.txt']
names[2] = ['ethane/b6dp.txt','ethane/cc6dp.txt','ethane/mo6dp.txt','ethane/mp6dp.txt']
names[3] = ['ethane/blan.txt','ethane/cclan.txt','ethane/molan.txt','ethane/mplan.txt']
names[4] = ['ethane/bsto.txt','ethane/ccsto.txt','ethane/mosto.txt','ethane/mpsto.txt']
legends = ['B3LYP','CCSD','M062X','MP2']
legends1 = ['B3LYP','M062X','MP2']

# %%
for name in names:
    plt.figure()
    for i in range(len(name)):
        data = pd.read_csv(name[i], sep=' ',skipinitialspace=True, skiprows=6)
        data.columns = ['a','b','c']
        data.b = data.b * 627.509
        plt.plot(data.a,data.b)
        plt.xlabel('Optimization Step')
        plt.ylabel('Energy (kcal/mol)')
    plt.legend(legends)
    plt.show()

# %% [markdown]
# ### The graphs for Ethene according to the basis sets in the following order:
# 1)321
# 2)6-31Gd
# 3)6-31Gdp
# 4)LANL2DZ
# 5)STO-3G

# %%
names = [[] for i in range(0,5)]

# %%
names[0] = ['ethene/b31.txt','ethene/cc3.txt','ethene/mo3.txt','ethene/mp3.txt']
names[1] = ['ethene/b6d.txt','ethene/cc6d.txt','ethene/mo6d.txt','ethene/mp6d.txt']
names[2] = ['ethene/b6dp.txt','ethene/cc6dp.txt','ethene/mo6dp.txt','ethene/mp6dp.txt']
names[3] = ['ethene/blan.txt','ethene/cclan.txt','ethene/molan.txt','ethene/mplan.txt']
names[4] = ['ethene/bsto.txt','ethene/ccsto.txt','ethene/mosto.txt','ethene/mpsto.txt']
legends = ['B3LYP','CCSD','M062X','MP2']
legends1 = ['B3LYP','M062X','MP2']

# %%
for name in names:
    plt.figure()
    for i in range(len(name)):
        data = pd.read_csv(name[i], sep=' ',skipinitialspace=True, skiprows=6)
        data.columns = ['a','b','c']
        data.b = data.b * 627.509
        plt.plot(data.a,data.b)
        plt.xlabel('Optimization Step')
        plt.ylabel('Energy (kcal/mol)')
    plt.legend(legends)
    plt.show()

# %% [markdown]
# ### The graphs for Ethyne according to the basis sets in the following order:
# 1)321
# 2)6-31Gd
# 3)6-31Gdp
# 4)LANL2DZ
# 5)STO-3G

# %%
names = [[] for i in range(0,5)]

# %%
names[0] = ['ethyne/b3.txt','ethyne/cc3.txt','ethyne/mo3.txt','ethyne/mp3.txt']
names[1] = ['ethyne/b6d.txt','ethyne/cc6d.txt','ethyne/mo6d.txt','ethyne/mp6d.txt']
names[2] = ['ethyne/b6dp.txt','ethyne/cc6dp.txt','ethyne/mo6dp.txt','ethyne/mp6dp.txt']
names[3] = ['ethyne/blan.txt','ethyne/cclan.txt','ethyne/molan.txt','ethyne/mplan.txt']
names[4] = ['ethyne/bsto.txt','ethyne/ccsto.txt','ethyne/mosto.txt','ethyne/mpsto.txt']
legends = ['B3LYP','CCSD','M062X','MP2']
legends1 = ['B3LYP','M062X','MP2']

# %%
for name in names:
    plt.figure()
    for i in range(len(name)):
        data = pd.read_csv(name[i], sep=' ',skipinitialspace=True, skiprows=6)
        data.columns = ['a','b','c']
        data.b = data.b * 627.509
        plt.plot(data.a,data.b)
        plt.xlabel('Optimization Step')
        plt.ylabel('Energy (kcal/mol)')
    plt.legend(legends)
    plt.show()

# %% [markdown]
# ### STO-3G
# The most common minimal basis set is STO-nG, where n is an integer. This n value represents the number of Gaussian primitive functions comprising a single basis function. In these basis sets, the same number of Gaussian primitives comprise core and valence orbitals.

# %% [markdown]
# ### Pople basis sets-321,6-31Gd,6-31Gdp
# The notation for the split-valence basis sets arising from the group of John Pople is typically X-YZg. In this case, X represents the number of primitive Gaussians comprising each core atomic orbital basis function. The Y and Z indicate that the valence orbitals are composed of two basis functions each, the first one composed of a linear combination of Y primitive Gaussian functions, the other composed of a linear combination of Z primitive Gaussian functions. In this case, the presence of two numbers after the hyphens implies that this basis set is a split-valence double-zeta basis set.

# %% [markdown]
# ### LANL2DZ
# Los Alamos National Laboratory (LANL) effective core potentials

# %% [markdown]
# ### B3LYP
# B3LYP is a hybrid functional developed in the late 80s.  It turns out that DFT and Hartree-Fock based methods are basically trying to do the same thing - recover electron correlation.It is popular for many reasons. It was one of the first DFT methods that was a significant improvement over Hartree-Fock. B3LYP is generally faster than most Post Hartree-Fock techniques and usually yields comparable results. It is also fairly robust for a DFT method.

# %% [markdown]
# ### CCSD
# Coupled cluster (CC) is a numerical technique used for describing many-body systems. Its most common use is as one of several post-Hartree–Fock ab initio quantum chemistry methods in the field of computational chemistry, but it is also used in nuclear physics. Coupled cluster essentially takes the basic Hartree–Fock molecular orbital method and constructs multi-electron wavefunctions using the exponential cluster operator to account for electron correlation. Some of the most accurate calculations for small to medium-sized molecules use this method.

# %% [markdown]
# ### MP2
# Møller–Plesset perturbation theory (MP) is one of several quantum chemistry post-Hartree–Fock ab initio methods in the field of computational chemistry. It improves on the Hartree–Fock method by adding electron correlation effects by means of Rayleigh–Schrödinger perturbation theory (RS-PT), usually to second (MP2), third (MP3) or fourth (MP4) order.

# %% [markdown]
# ### M062X
# Minnesota Functionals (Myz) are a group of approximate exchange-correlation energy functionals in density functional theory (DFT).These functionals are based on the meta-GGA approximation, i.e. they include terms that depend on the kinetic energy density, and are all based on complicated functional forms parametrized on high-quality benchmark databases. These functionals can be used for traditional quantum chemistry and solid-state physics calculations.
