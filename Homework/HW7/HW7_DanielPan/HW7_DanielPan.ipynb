# %% [markdown]
# # HW7

# %%
import pandas as pd

# %%
data = pd.read_table('HW7.csv',delimiter=',')

# %% [markdown]
# ## Avogadro

# %%
data.iloc[0:7][['Avogadro','atom','GAFF','UFF','exp']]
# Out:
#   Avogadro atom   GAFF    UFF    exp
# 0      H-H  H-H    1.1  0.708  0.741
# 1  H3C-CH3  C-C  1.537  1.519  1.526
# 2  H3C-CH4  C-H  1.092   1.11  1.088
# 3  H2C-CH2  C-C  1.325  1.331  1.339
# 4  H2C-CH3  C-H  1.087  1.085  1.085
# 5    HC-CH  C-C  1.205  1.205  1.203
# 6    HC-CH  C-H  1.058  1.058  1.061

# %% [markdown]
# ## STO-3G

# %%
s = pd.read_table('HW7.csv',delimiter=',',skiprows=8)
s.iloc[0:11]
# Out:
#      STO-3G  atom    B3YLP      MP2     CCSD    M062X    exp
# 0       H-H   H-H  0.72838  0.72374  0.70801  0.72206  0.741
# 1       H-H  time     21.5     24.6        4     23.5      x
# 2   H3C-CH3   C-C  1.55123  1.55541  1.56303  1.54109  1.526
# 3   H3C-CH4   C-H  1.10097  1.10309  1.11147   1.0957  1.088
# 4   H3C-CH5  time     23.4     29.9     62.4     25.6      x
# 5   H2C-CH2   C-C  1.33309  1.34529   1.3549  1.32245  1.339
# 6   H2C-CH3   C-H  1.09728  1.09832  1.10609  1.09227  1.085
# 7   H2C-CH4  time     25.5     22.9     48.2     30.7      x
# 8     HC-CH   C-C  1.20055  1.21829  1.21263   1.1926  1.203
# 9     HC-CH   C-H  1.08084   1.0807  1.08783  1.07782  1.061
# 10    HC-CH  time     26.7       31     59.8       27      x

# %% [markdown]
# ## 3-21G

# %%
g3 = pd.read_table('HW7.csv',delimiter=',',skiprows=20)
g3.iloc[0:11]
# Out:
#       3-21G  atom    B3YLP      MP2     CCSD    M062X    exp
# 0       H-H   H-H  0.74623  0.74136  0.74981  0.74145  0.741
# 1       H-H  time     12.8     10.3     19.7      9.7      x
# 2   H3C-CH3   C-C  1.54478  1.55083  1.55624   1.5431  1.526
# 3   H3C-CH4   C-H  1.09556  1.09481  1.09932  1.09412  1.088
# 4   H3C-CH5  time     24.6     27.9     75.9     30.9      x
# 5   H2C-CH2   C-C  1.32941  1.34115  1.34387    1.328  1.339
# 6   H2C-CH3   C-H  1.08586   1.0856  1.08976  1.08468  1.085
# 7   H2C-CH4  time     31.7     23.1     61.5     34.6      x
# 8     HC-CH   C-C  1.20366  1.22169  1.21683  1.20226  1.203
# 9     HC-CH   C-H  1.06224  1.06429  1.06837  1.06209  1.061
# 10    HC-CH  time     39.1     32.7     74.6     22.8      x

# %% [markdown]
# ## 6-31G(d)

# %%
gd = pd.read_table('HW7.csv',delimiter=',',skiprows=32)
gd.iloc[0:11]
# Out:
#    6-31G(d)  atom    B3YLP      MP2     CCSD    M062X    exp
# 0       H-H   H-H  0.74279  0.73752  0.74621  0.73653  0.741
# 1       H-H  time     12.4     14.1     18.7     12.6      x
# 2   H3C-CH3   C-C  1.53114  1.52527  1.52904  1.52572  1.526
# 3   H3C-CH4   C-H  1.09629  1.09327  1.09686  1.09391  1.088
# 4   H3C-CH5  time     31.2     33.8      165     38.5      x
# 5   H2C-CH2   C-C  1.33094  1.33662   1.3379  1.32744  1.339
# 6   H2C-CH3   C-H  1.08749  1.08505  1.08803   1.0859  1.085
# 7   H2C-CH4  time       42     37.5    153.4     41.2      x
# 8     HC-CH   C-C  1.20498  1.21768  1.21151  1.20193  1.203
# 9     HC-CH   C-H  1.06664  1.06614   1.0687  1.06712  1.061
# 10    HC-CH  time     44.3     35.7    124.3     28.4      x

# %% [markdown]
# ## 6-31G(d,p)

# %%
gdp = pd.read_table('HW7.csv',delimiter=',',skiprows=44)
gdp.iloc[0:11]
# Out:
#    6-31G(d,p)  atom    B3YLP      MP2     CCSD    M062X    exp
# 0         H-H   H-H   0.7428  0.73393  0.73845  0.73649  0.741
# 1         H-H  time     15.3     12.9     24.3     11.5      x
# 2     H3C-CH3   C-C  1.53054  1.52345  1.52671  1.52543  1.526
# 3     H3C-CH4   C-H  1.09513  1.08872  1.09047  1.09316  1.088
# 4     H3C-CH5  time     35.2       40    483.5     44.3      x
# 5     H2C-CH2   C-C  1.33016  1.33535  1.33646  1.32687  1.339
# 6     H2C-CH3   C-H  1.08666  1.08065  1.08188  1.08541  1.085
# 7     H2C-CH4  time     50.1     44.1      324     47.1      x
# 8       HC-CH   C-C  1.20535  1.21855  1.21213  1.20235  1.203
# 9       HC-CH   C-H  1.06572  1.06245  1.06365  1.06643  1.061
# 10      HC-CH  time     33.2     41.9    140.7     31.1      x

# %% [markdown]
# ## LANL2DZ

# %%
l = pd.read_table('HW7.csv',delimiter=',',skiprows=56)
l.iloc[0:11]
# Out:
#     LANL2DZ  atom     B3YLP       MP2      CCSD     M062X    exp
# 0       H-H   H-H   0.74348   0.73835   0.74730   0.73747  0.741
# 1       H-H  time  13.20000  14.80000  19.20000  13.40000      x
# 2   H3C-CH3   C-C   1.54356   1.56173   1.56506   1.53924  1.526
# 3   H3C-CH4   C-H   1.09795   1.10492   1.10925   1.09492  1.088
# 4   H3C-CH5  time  31.30000  27.00000  78.60000  31.90000      x
# 5   H2C-CH2   C-C   1.34836   1.36762   1.36970   1.34312  1.339
# 6   H2C-CH3   C-H   1.08841   1.09413   1.09782   1.08628  1.085
# 7   H2C-CH4  time  27.10000  25.50000  65.90000  37.30000      x
# 8     HC-CH   C-C   1.22228   1.24606   1.23941   1.21687  1.203
# 9     HC-CH   C-H   1.06783   1.07186   1.07543   1.06706  1.061
# 10    HC-CH  time  43.70000  27.50000  73.80000  26.30000      x

# %% [markdown]
# ##  Hydrogen
# <img src="files/png/HH_STO-3G.png">
# <img src="files/png/HH_3-21G.png">
# <img src="files/png/HH_6gd.png">
# <img src="files/png/HH_6gdp.png">
# <img src="files/png/HH_LANL2DZ.png">

# %% [markdown]
# ## Ethane
# <img src="files/png/CH3_STO-3G.png">
# <img src="files/png/CH3_3-21G.png">
# <img src="files/png/CH3_6gd.png">
# <img src="files/png/CH3_6gdp.png">
# <img src="files/png/CH3_LANL2DZ.png">

# %% [markdown]
# ## Ethene
# <img src="files/png/CH2_STO-3G.png">
# <img src="files/png/CH2_3-21G.png">
# <img src="files/png/CH2_6gd.png">
# <img src="files/png/CH2_6gdp.png">
# <img src="files/png/CH2_LANL2DZ.png">

# %% [markdown]
# ## Ethyne
# <img src="files/png/CH_STO-3G.png">
# <img src="files/png/CH_3-21G.png">
# <img src="files/png/CH_6gd.png">
# <img src="files/png/CH_6gdp.png">
# <img src="files/png/CH_LANL2DZ.png">

# %% [markdown]
# ## Questions:
# 1. What level of theory and basis set gave the best values, compared with the experimental one?
#     * Looks like theory = MP2 and B3LYP get closer values to exp, and basis = 6-31G(d) do too.
# 2. What was the fastest calculation?
#     * Basis = STO-3G, or theory = M062X, or H2 got fastest calculation.

# %% [markdown]
# ## Theory:
# 1. B3LYP
#     * B3LYP is a hybrid functional in which the exchange energy, and combined with the exact energy from Hartree–Fock theory. Along with the component exchange and correlation funсtionals, three parameters define the hybrid functional, specifying how much of the exact exchange is mixed in.
# 2. MP2
#     * Møller–Plesset perturbation theory (MP) is one of several quantum chemistry post-Hartree–Fock ab initio methods in the field of computational chemistry. It improves on the Hartree–Fock method by adding electron correlation effects by means of Rayleigh–Schrödinger perturbation theory (RS-PT).
# 3. CCSD
#     * Coupled cluster(CC) takes the basic Hartree–Fock molecular orbital method and constructs multi-electron wavefunctions using the exponential cluster operator to account for electron correlation. (S – for single excitations, D – for double excitations )
# 4. M062X
#     * Minnesota Functionals (Myz) are a group of approximate exchange-correlation energy functionals in density functional theory (DFT). These functionals are based on the meta-GGA approximation, and can be used for traditional quantum chemistry and solid-state physics calculations.

# %% [markdown]
# ## Basis:
# 1. STO-3G
#     * STO-nG basis sets are minimal basis sets, where n primitive Gaussian orbitals are fitted to a single Slater-type orbital (STO). n originally took the values 2 - 6. A minimum basis set is where only sufficient orbitals are used to contain all the electrons in the neutral atom.
# 2. 3-21G
#     * Pople basis sets, X-YZg. X represents the number of primitive Gaussians comprising each core atomic orbital basis function. The Y and Z indicate that the valence orbitals are composed of two basis functions each, the first one composed of a linear combination of Y primitive Gaussian functions, the other composed of a linear combination of Z primitive Gaussian functions.
# 3. 6-31G(d)
#     * See 2, and one set of d-type polarization functions is added to all non-hydrogens.
# 4. 6-31G(d,p)
#     * See 3, and one set of p-type polarization functions added to hydrogen atoms.
# 5. LANL2DZ
#     * Los Alamos National Laboratory (LANL) effective core potentials. This type of pseudo-potential is available for a variety of elements together with the appropriate valence basis set. The latter is of double zeta (DZ) quality and the overall combination of ECP and valence basis set is thus referred to as "LANL2DZ" basis.
