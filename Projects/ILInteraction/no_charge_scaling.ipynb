# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BMI_CHL_BMI=pd.read_table('./data_charges_PE/PE_BMI_CHL_BMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
BMI_CHL_SALT=pd.read_table('./data_charges_PE/PE_BMI_CHL_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
BMI_CHL_CHL=pd.DataFrame(data=np.zeros((len(BMI_CHL_BMI['cation']),1)),columns=['anion'])
BMI_CHL = pd.concat([BMI_CHL_BMI['Step'],BMI_CHL_BMI['cation'],BMI_CHL_CHL['anion'],BMI_CHL_SALT['SALT']], axis=1)

BAM_FOR_BAM= pd.read_table('./data_charges_PE/PE_BAM_FOR_BAM.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
BAM_FOR_FOR= pd.read_table('./data_charges_PE/PE_BAM_FOR_FOR.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
BAM_FOR_SALT=pd.read_table('./data_charges_PE/PE_BAM_FOR_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
BAM_FOR = pd.concat([BAM_FOR_BAM['Step'],BAM_FOR_BAM['cation'],BAM_FOR_FOR['anion'],BAM_FOR_SALT['SALT']], axis=1)

BMI_ACE_ACE= pd.read_table('./data_charges_PE/PE_BMI_ACE_ACE.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
BMI_ACE_BMI= pd.read_table('./data_charges_PE/PE_BMI_ACE_BMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
BMI_ACE_SALT=pd.read_table('./data_charges_PE/PE_BMI_ACE_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
BMI_ACE = pd.concat([BMI_ACE_ACE['Step'],BMI_ACE_ACE['cation'],BMI_ACE_BMI['anion'],BMI_ACE_SALT['SALT']], axis=1)

BMI_MTS_BMI=pd.read_table('./data_charges_PE/PE_BMI_MTS_BMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
BMI_MTS_MTS=pd.read_table('./data_charges_PE/PE_BMI_MTS_MTS.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
BMI_MTS_SALT=pd.read_table('./data_charges_PE/PE_BMI_MTS_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
BMI_MTS = pd.concat([BMI_MTS_BMI['Step'],BMI_MTS_BMI['cation'],BMI_MTS_MTS['anion'],BMI_MTS_SALT['SALT']], axis=1)

BMI_TF2_BMI=pd.read_table('./data_charges_PE/PE_BMI_TF2_BMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
BMI_TF2_TF2=pd.read_table('./data_charges_PE/PE_BMI_TF2_TF2.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
BMI_TF2_SALT=pd.read_table('./data_charges_PE/PE_BMI_TF2_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
BMI_TF2 = pd.concat([BMI_TF2_BMI['Step'],BMI_TF2_BMI['cation'],BMI_TF2_TF2['anion'],BMI_TF2_SALT['SALT']], axis=1)

EAM_FOR_EAM=pd.read_table('./data_charges_PE/PE_EAM_FOR_EAM.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
EAM_FOR_FOR=pd.read_table('./data_charges_PE/PE_EAM_FOR_FOR.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
EAM_FOR_SALT=pd.read_table('./data_charges_PE/PE_EAM_FOR_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
EAM_FOR = pd.concat([EAM_FOR_EAM['Step'],EAM_FOR_EAM['cation'],EAM_FOR_FOR['anion'],EAM_FOR_SALT['SALT']], axis=1)

EMI_ACE_EMI=pd.read_table('./data_charges_PE/PE_EMI_ACE_EMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
EMI_ACE_ACE=pd.read_table('./data_charges_PE/PE_EMI_ACE_ACE.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
EMI_ACE_SALT=pd.read_table('./data_charges_PE/PE_EMI_ACE_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
EMI_ACE = pd.concat([EMI_ACE_EMI['Step'],EMI_ACE_EMI['cation'],EMI_ACE_ACE['anion'],EMI_ACE_SALT['SALT']], axis=1)

EMI_ETS_EMI=pd.read_table('./data_charges_PE/PE_EMI_ETS_EMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
EMI_ETS_ETS=pd.read_table('./data_charges_PE/PE_EMI_ETS_ETS.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
EMI_ETS_SALT=pd.read_table('./data_charges_PE/PE_EMI_ETS_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
EMI_ETS = pd.concat([EMI_ETS_EMI['Step'],EMI_ETS_EMI['cation'],EMI_ETS_ETS['anion'],EMI_ETS_SALT['SALT']], axis=1)

EMI_FMS_EMI=pd.read_table('./data_charges_PE/PE_EMI_FMS_EMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
EMI_FMS_FMS=pd.read_table('./data_charges_PE/PE_EMI_FMS_FMS.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
EMI_FMS_SALT=pd.read_table('./data_charges_PE/PE_EMI_FMS_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
EMI_FMS = pd.concat([EMI_FMS_EMI['Step'],EMI_FMS_EMI['cation'],EMI_FMS_FMS['anion'],EMI_FMS_SALT['SALT']], axis=1)

EMI_TF2_EMI=pd.read_table('./data_charges_PE/PE_EMI_TF2_EMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
EMI_TF2_TF2=pd.read_table('./data_charges_PE/PE_EMI_TF2_TF2.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
EMI_TF2_SALT=pd.read_table('./data_charges_PE/PE_EMI_TF2_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
EMI_TF2 = pd.concat([EMI_TF2_EMI['Step'],EMI_TF2_EMI['cation'],EMI_TF2_TF2['anion'],EMI_TF2_SALT['SALT']], axis=1)

EPY_ETS_EPY=pd.read_table('./data_charges_PE/PE_EPY_ETS_EPY.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
EPY_ETS_ETS=pd.read_table('./data_charges_PE/PE_EPY_ETS_ETS.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
EPY_ETS_SALT=pd.read_table('./data_charges_PE/PE_EPY_ETS_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
EPY_ETS = pd.concat([EPY_ETS_EPY['Step'],EPY_ETS_EPY['cation'],EPY_ETS_ETS['anion'],EPY_ETS_SALT['SALT']], axis=1)

EPY_TF2_EPY=pd.read_table('./data_charges_PE/PE_EPY_TF2_EPY.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
EPY_TF2_TF2=pd.read_table('./data_charges_PE/PE_EPY_TF2_TF2.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
EPY_TF2_SALT=pd.read_table('./data_charges_PE/PE_EPY_TF2_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
EPY_TF2 = pd.concat([EPY_TF2_EPY['Step'],EPY_TF2_EPY['cation'],EPY_TF2_TF2['anion'],EPY_TF2_SALT['SALT']], axis=1)

HMI_CHL_HMI=pd.read_table('./data_charges_PE/PE_HMI_CHL_HMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
HMI_CHL_SALT=pd.read_table('./data_charges_PE/PE_HMI_CHL_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
HMI_CHL_CHL=pd.DataFrame(data=np.zeros((len(HMI_CHL_HMI['cation']),1)),columns=['anion'])
HMI_CHL = pd.concat([HMI_CHL_HMI['Step'],HMI_CHL_HMI['cation'],HMI_CHL_CHL['anion'],HMI_CHL_SALT['SALT']], axis=1)

HMI_TF2_HMI=pd.read_table('./data_charges_PE/PE_HMI_TF2_HMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
HMI_TF2_TF2=pd.read_table('./data_charges_PE/PE_HMI_TF2_TF2.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
HMI_TF2_SALT=pd.read_table('./data_charges_PE/PE_HMI_TF2_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
HMI_TF2 = pd.concat([HMI_TF2_HMI['Step'],HMI_TF2_HMI['cation'],HMI_TF2_TF2['anion'],HMI_TF2_SALT['SALT']], axis=1)

HPY_TF2_HPY=pd.read_table('./data_charges_PE/PE_HPY_TF2_HPY.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
HPY_TF2_TF2=pd.read_table('./data_charges_PE/PE_HPY_TF2_TF2.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
HPY_TF2_SALT=pd.read_table('./data_charges_PE/PE_HPY_TF2_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
HPY_TF2 = pd.concat([HPY_TF2_HPY['Step'],HPY_TF2_HPY['cation'],HPY_TF2_TF2['anion'],HPY_TF2_SALT['SALT']], axis=1)

OMI_CHL_HMI=pd.read_table('./data_charges_PE/PE_OMI_CHL_OMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
OMI_CHL_SALT=pd.read_table('./data_charges_PE/PE_OMI_CHL_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
OMI_CHL_CHL=pd.DataFrame(data=np.zeros((len(OMI_CHL_HMI['cation']),1)),columns=['anion'])
OMI_CHL = pd.concat([OMI_CHL_HMI['Step'],OMI_CHL_HMI['cation'],OMI_CHL_CHL['anion'],OMI_CHL_SALT['SALT']], axis=1)

OMI_FMS_OMI=pd.read_table('./data_charges_PE/PE_OMI_FMS_OMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
OMI_FMS_FMS=pd.read_table('./data_charges_PE/PE_OMI_FMS_FMS.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
OMI_FMS_SALT=pd.read_table('./data_charges_PE/PE_OMI_FMS_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
OMI_FMS = pd.concat([OMI_FMS_OMI['Step'],OMI_FMS_OMI['cation'],OMI_FMS_FMS['anion'],OMI_FMS_SALT['SALT']], axis=1)

OMI_TF2_OMI=pd.read_csv('./data_charges_PE/PE_OMI_TF2_OMI.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
OMI_TF2_TF2=pd.read_csv('./data_charges_PE/PE_OMI_TF2_TF2.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
OMI_TF2_SALT=pd.read_csv('./data_charges_PE/PE_OMI_TF2_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
OMI_TF2 = pd.concat([OMI_TF2_OMI['Step'],OMI_TF2_OMI['cation'],OMI_TF2_TF2['anion'],OMI_TF2_SALT['SALT']], axis=1)

PAM_FOR_PAM=pd.read_csv('./data_charges_PE/PE_PAM_FOR_PAM.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
PAM_FOR_FOR=pd.read_csv('./data_charges_PE/PE_PAM_FOR_FOR.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
PAM_FOR_SALT=pd.read_csv('./data_charges_PE/PE_PAM_FOR_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
PAM_FOR = pd.concat([PAM_FOR_PAM['Step'],PAM_FOR_PAM['cation'],PAM_FOR_FOR['anion'],PAM_FOR_SALT['SALT']], axis=1)

PPY_TF2_PPY=pd.read_csv('./data_charges_PE/PE_PPY_TF2_PPY.xvg',skiprows=23,delim_whitespace= True,names=['Step','cation'])
PPY_TF2_TF2=pd.read_csv('./data_charges_PE/PE_PPY_TF2_TF2.xvg',skiprows=23,delim_whitespace= True,names=['Step','anion'])
PPY_TF2_SALT=pd.read_csv('./data_charges_PE/PE_PPY_TF2_SALT.xvg',skiprows=23,delim_whitespace= True,names=['Step','SALT'])
PPY_TF2 = pd.concat([PPY_TF2_PPY['Step'],PPY_TF2_PPY['cation'],PPY_TF2_TF2['anion'],PPY_TF2_SALT['SALT']], axis=1)

list_of_SALTs=[BMI_CHL,BAM_FOR,BMI_ACE,BMI_MTS,BMI_TF2,EAM_FOR,EMI_ACE,EMI_ETS,EMI_FMS,EMI_TF2,EPY_ETS,EPY_TF2,HMI_CHL,HMI_TF2,HPY_TF2,OMI_CHL,OMI_FMS,OMI_TF2,PAM_FOR,PPY_TF2]
list_of_SALTs_b=np.array(['BMI_CHL', 'BAM_FOR','BMI_ACE','BMI_MTS','BMI_TF2','EAM_FOR','EMI_ACE','EMI_ETS','EMI_FMS','EMI_TF2','EPY_ETS','EPY_TF2','HMI_CHL','HMI_TF2','HPY_TF2','OMI_CHL','OMI_FMS','OMI_TF2','PAM_FOR','PPY_TF2'])
df_of_SALTs_b=pd.DataFrame(['BMI_CHL', 'BAM_FOR','BMI_ACE','BMI_MTS','BMI_TF2','EAM_FOR','EMI_ACE','EMI_ETS','EMI_FMS','EMI_TF2','EPY_ETS','EPY_TF2','HMI_CHL','HMI_TF2','HPY_TF2','OMI_CHL','OMI_FMS','OMI_TF2','PAM_FOR','PPY_TF2'],columns=['SALT'])

print(df_of_SALTs_b)
# Out:
#        SALT
# 0   BMI_CHL
# 1   BAM_FOR
# 2   BMI_ACE
# 3   BMI_MTS
# 4   BMI_TF2
# 5   EAM_FOR
# 6   EMI_ACE
# 7   EMI_ETS
# 8   EMI_FMS
# 9   EMI_TF2
# 10  EPY_ETS
# 11  EPY_TF2
# 12  HMI_CHL
# 13  HMI_TF2
# 14  HPY_TF2
# 15  OMI_CHL
# 16  OMI_FMS
# 17  OMI_TF2
# 18  PAM_FOR
# 19  PPY_TF2

# %%
just_SALT=[]
indexer=0
SALTs=[]
average=[]
for SALTs in list_of_SALTs:
    for index in range(len(BAM_FOR)):
        just_SALT.append(SALTs.SALT.loc[index]-(SALTs.cation.loc[index]+SALTs.anion.loc[index]))
    SALT_array=[]
    SALT_array=np.array(just_SALT)
    SALT_array.transpose()
    SALTs['just_SALT']=pd.DataFrame(SALT_array)
    average.append(np.average(SALT_array))
    
    #plt.figure(figsize=[7,5])
    #plt.plot(SALTs['Step'],SALTs['cation'])
    #plt.plot(SALTs['Step'],SALTs['anion'])
    #plt.plot(SALTs['Step'],SALTs['SALT'])
    #plt.plot(SALTs['Step'],SALTs['just_SALT'])
    #plt.legend([list_of_SALTs_b[indexer][0:3:1],list_of_SALTs_b[indexer][4::],list_of_SALTs_b[indexer],'Subtracted'])
    #plt.ylabel('Total Energy (kJ/mol)')
    #plt.xlabel('Step')
    #plt.title([list_of_SALTs_b[indexer],average])
    indexer+=1

df_of_SALTs_b['Average PE']=pd.DataFrame(average)

df_of_SALTs_b.sort_values(by='Average PE')
print(df_of_SALTs_b.sort_values(by='Average PE'))
# Out:
#        SALT  Average PE
# 0   BMI_CHL -203.038974
# 1   BAM_FOR -191.776608
# 15  OMI_CHL -178.127147
# 19  PPY_TF2 -178.036101
# 18  PAM_FOR -177.798637
# 17  OMI_TF2 -177.745001
# 2   BMI_ACE -177.404868
# 5   EAM_FOR -176.229665
# 14  HPY_TF2 -175.885079
# 16  OMI_FMS -175.883658
# 13  HMI_TF2 -174.629228
# 6   EMI_ACE -172.792420
# 4   BMI_TF2 -172.667363
# 12  HMI_CHL -172.436191
# 9   EMI_TF2 -170.543033
# 7   EMI_ETS -170.487543
# 11  EPY_TF2 -170.227227
# 10  EPY_ETS -167.942339
# 8   EMI_FMS -166.543765
# 3   BMI_MTS -165.218527

# %%
#md=[-202.823,-193.216,-165.172,-177.719]
#qm=[-390.256,-495.905,-577.418,-452.720]
#plt.plot(md,qm,linestyle='None',marker='*')
