# %% [markdown]
# # Sometime you read discription like this:
# ## 1. HAP
# The original crystal structure of HAP <span style="color:red"><b>*(P63/m)*</b></span>. was extracted from the American Mineralogist Crystal Structure Database with <span style="color:red"><b>*unit cell parameters*</b></span> of a = b = 0.943 nm and c = 0.688 nm. ... The defective HAP <span style="color:red"><b>*(001)*</b></span> surface with Ca(1) <span style="color:red"><b>*vacancies*</b></span> is cut with half of the Ca(1) ions presented in the upper and lower interfaces21 (see Figure S1 in the Supporting Information) using Materials Studio 4.4 (Accelrys, Inc.).
# ## 2. TiO$_{2}$
# The <span style="color:red"><b>*rutile TiO2 unit cell*</b></span> belongs to <span style="color:red"><b>*space group P42/mnm*</b></span>, with <span style="color:red"><b>*lattice parameters a = b = 4.594 Å and c = 2.959 Å (the unit cell angles are all 90°)*</b></span>. The unit cell was <span style="color:red"><b>*replicated and cleaved either along the (100) plane or along the (110) plane*</b></span>.
# ## 3. Silica
# Models of <span style="color:red"><b>*unit cells of α-cristobalite and α-quartz*</b></span> were obtained from published X-ray crystal structures to create <span style="color:red"><b>*super cells*</b></span> of the minerals. Models of regular Q3 and Q2 surfaces of approximately ~3.5×3.5 nm2 surface area were obtained by <span style="color:red"><b>*cleavage of the (10$\overline{1}$) plane of α-cristobalite and of the (100) plane of α-quartz*</b></span>, respectively,
# followed by hydration of dissociated bonds to silanol groups

# %% [markdown]
# # All you need to know about Materials Science/Crystallography
# * Crystalline, Unit cell
# * Common crystal structure BCC FCC HCP
# * Bravis Lattice
# * Space group
# * Miller indice
# * Defects
#
#
# *Note: all the figures and text are from materials science bible: Materials Science and Engineering: An Introduction, 9th Edition: Ninth Edition By William D. Callister, David G. Rethwisch*

# %% [markdown]
# # Crystal Structure
# ## Crystalline and Noncrystalline
# ![alt text](./pic/crystalline.png "crystal and non crystals")
# A crystal or crystalline solid is a solid material whose constituents (such as atoms, molecules, or ions) are arranged in a highly ordered microscopic structure, forming a crystal lattice that extends in all directions.
# ## Unit cell
# In describing crystal structures, it is often convenient to subdivide the structure into small repeat entities called unit cells. A unit cell is chosen to represent the symmetry of the crystal structure, wherein all the atom positions in the crystal may be generated by translations of the unit cell integral distances along each of its edges.
# # Common crystal structure
# ## Simple cubic
# ![alt text](./pic/simplecubic.png "simple cubic")
# For the simple cubic crystal structure, (a) a hard-sphere unit cell, and (b) a reduced-sphere unit cell.
# ## Body-Centered Crystal (BCC)
# ![alt text](./pic/BCC.png "BCC unitcell")
# For the simple cubic crystal structure, (a) a hard-sphere unit cell, and (b) a reduced-sphere unit cell.
#
# Materials with BCC structure:lithium, sodium, potassium, chromium, barium, vanadium, alpha-iron and tungsten
# ## Face-Centered Crystal (FCC)
# ![alt text](./pic/FCC.png "FCC unitcell")
# For the face-centered cubic crystal structure, (a) a hard-sphere unit cell representation, (b) a reduced- sphere unit cell, and (c) an aggregate of many atoms.
#
# Materials that are FCC: aluminum, copper, gold, iridium, lead, nickel, platinum and silver.
# ## Hexagonal Close-Packed (HCP)
# ![alt text](./pic/HCP.png "HCP unitcell")
# # Bravais lattices
# ![alt text](./pic/bravais.png  "14 Bravais lattices")
# #### Simulation box is a unit cell!
# ![alt text](./pic/pdb.png "pdb head")
# # Space group
# Always check space group!
# ![alt text](./pic/spacegroup.png "table of space group")
# # Miller Indice
# ![alt text](./pic/Miller_Indices.png "Miller_Indices for plane")
# # Defects
# Vacancy and interstitial
# ![alt text](./pic/Frenkel.png "Interstitial and vacancy")

# %% [markdown]
# # Let's make some slabs!
# * Find the right unitcell sturcture using all the terms we learn!
#     Rutile TiO$_2$, P42/mnm, a = b = 4.594 Å and c = 2.959 Å
#     [Crystallography Open Database](http://www.crystallography.net/cod/)
# * Build slab:
#     * Avogadro
#     * Virtual Nanolab
# * Cleavage and termination

# %% [markdown]
# # Homework
# Make the following slabs and upload the pdb file.
# 1. Silica α-quartz (100) plane, approximately ~3.5×3.5 nm$^2$,cleave the Si on the surface and add H to O atom.
# 2. Rutile TiO$_2$ , P42/mnm, with lattice parameters a = b = 4.594 Å and c = 2.959 Å (110) plane. Specify the size of the slab you made.
